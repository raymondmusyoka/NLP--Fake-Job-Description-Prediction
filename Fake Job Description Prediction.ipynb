# %% [markdown]
# # INTRODUCTION

# %% [markdown]
#  ##### Fake Job Description Prediction
# This dataset contains 18K job descriptions out of which about 800 are fake. The data consists of both textual information and meta-information about the jobs. The dataset can be used to create classification models which can learn the job descriptions which are fraudulent.

# %% [markdown]
# #### Data source
# http://emscad.samos.aegean.gr/

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the datasets

# %%
data =pd.read_csv("fake_job_postings.csv")
data.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
# 3  THE COMPANY: ESRI – Environmental Systems Rese...
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
# 3  EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4  QUALIFICATIONS:RN license in the State of Texa...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
# 3  Our culture is anything but corporate—we have ...              0
# 4                              Full Benefits Offered              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
# 3                 1              0       Full-time    Mid-Senior level
# 4                 1              1       Full-time    Mid-Senior level
#
#   required_education                   industry              function  \
# 0                NaN                        NaN             Marketing
# 1                NaN  Marketing and Advertising      Customer Service
# 2                NaN                        NaN                   NaN
# 3  Bachelor's Degree          Computer Software                 Sales
# 4  Bachelor's Degree     Hospital & Health Care  Health Care Provider
#
#    fraudulent
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
data.info
# Out:
# <bound method DataFrame.info of        job_id                                              title  \
# 0           1                                   Marketing Intern
# 1           2          Customer Service - Cloud Video Production
# 2           3            Commissioning Machinery Assistant (CMA)
# 3           4                  Account Executive - Washington DC
# 4           5                                Bill Review Manager
# ...       ...                                                ...
# 17875   17876                   Account Director - Distribution
# 17876   17877                                 Payroll Accountant
# 17877   17878  Project Cost Control Staff Engineer - Cost Con...
# 17878   17879                                   Graphic Designer
# 17879   17880                         Web Application Developers
#
#                    location   department salary_range  \
# 0          US, NY, New York    Marketing          NaN
# 1            NZ, , Auckland      Success          NaN
# 2             US, IA, Wever          NaN          NaN
# 3        US, DC, Washington        Sales          NaN
# 4        US, FL, Fort Worth          NaN          NaN
# ...                     ...          ...          ...
# 17875       CA, ON, Toronto        Sales          NaN
# 17876  US, PA, Philadelphia   Accounting          NaN
# 17877       US, TX, Houston          NaN          NaN
# 17878         NG, LA, Lagos          NaN          NaN
# 17879     NZ, N, Wellington  Engineering          NaN
#
#                                          company_profile  \
# 0      We're Food52, and we've created a groundbreaki...
# 1      90 Seconds, the worlds Cloud Video Production ...
# 2      Valor Services provides Workforce Solutions th...
# 3      Our passion for improving quality of life thro...
# 4      SpotSource Solutions LLC is a Global Human Cap...
# ...                                                  ...
# 17875  Vend is looking for some awesome new talent to...
# 17876  WebLinc is the e-commerce platform and service...
# 17877  We Provide Full Time Permanent Positions for m...
# 17878                                                NaN
# 17879  Vend is looking for some awesome new talent to...
#
#                                              description  \
# 0      Food52, a fast-growing, James Beard Award-winn...
# 1      Organised - Focused - Vibrant - Awesome!Do you...
# 2      Our client, located in Houston, is actively se...
# 3      THE COMPANY: ESRI – Environmental Systems Rese...
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...
# ...                                                  ...
# 17875  Just in case this is the first time you’ve vis...
# 17876  The Payroll Accountant will focus primarily on...
# 17877  Experienced Project Cost Control Staff Enginee...
# 17878  Nemsia Studios is looking for an experienced v...
# 17879  Who are we?Vend is an award winning web based ...
#
#                                             requirements  \
# 0      Experience with content management systems a m...
# 1      What we expect from you:Your key responsibilit...
# 2      Implement pre-commissioning and commissioning ...
# 3      EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4      QUALIFICATIONS:RN license in the State of Texa...
# ...                                                  ...
# 17875  To ace this role you:Will eat comprehensive St...
# 17876  - B.A. or B.S. in Accounting- Desire to have f...
# 17877  At least 12 years professional experience.Abil...
# 17878  1. Must be fluent in the latest versions of Co...
# 17879  We want to hear from you if:You have an in-dep...
#
#                                                 benefits  telecommuting  \
# 0                                                    NaN              0
# 1      What you will get from usThrough being part of...              0
# 2                                                    NaN              0
# 3      Our culture is anything but corporate—we have ...              0
# 4                                  Full Benefits Offered              0
# ...                                                  ...            ...
# 17875  What can you expect from us?We have an open cu...              0
# 17876  Health &amp; WellnessMedical planPrescription ...              0
# 17877                                                NaN              0
# 17878  Competitive salary (compensation will be based...              0
# 17879                                                NaN              0
#
#        has_company_logo  has_questions employment_type required_experience  \
# 0                     1              0           Other          Internship
# 1                     1              0       Full-time      Not Applicable
# 2                     1              0             NaN                 NaN
# 3                     1              0       Full-time    Mid-Senior level
# 4                     1              1       Full-time    Mid-Senior level
# ...                 ...            ...             ...                 ...
# 17875                 1              1       Full-time    Mid-Senior level
# 17876                 1              1       Full-time    Mid-Senior level
# 17877                 0              0       Full-time                 NaN
# 17878                 0              1        Contract      Not Applicable
# 17879                 1              1       Full-time    Mid-Senior level
#
#       required_education                   industry              function  \
# 0                    NaN                        NaN             Marketing
# 1                    NaN  Marketing and Advertising      Customer Service
# 2                    NaN                        NaN                   NaN
# 3      Bachelor's Degree          Computer Software                 Sales
# 4      Bachelor's Degree     Hospital & Health Care  Health Care Provider
# ...                  ...                        ...                   ...
# 17875                NaN          Computer Software                 Sales
# 17876  Bachelor's Degree                   Internet   Accounting/Auditing
# 17877                NaN                        NaN                   NaN
# 17878       Professional             Graphic Design                Design
# 17879                NaN          Computer Software           Engineering
#
#        fraudulent
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 17875           0
# 17876           0
# 17877           0
# 17878           0
# 17879           0
#
# [17880 rows x 18 columns]>

# %% [markdown]
# ## EDA

# %%
data.isna().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2695
# benefits                7210
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
data.fraudulent.value_counts()
# Out:
# 0    17014
# 1      866
# Name: fraudulent, dtype: int64

# %% [markdown]
# #### 0 stands for real job posting descriptions while 1 stands for fake job postings.

# %%
data.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %%
#fix spaces and column names
data.columns= data.columns.str.strip()
data.columns
# Out:
# Index(['job_id', 'title', 'location', 'department', 'salary_range',
#        'company_profile', 'description', 'requirements', 'benefits',
#        'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function',
#        'fraudulent'],
#       dtype='object')

# %%
#Reduce the number of columns with no useful
columns_to_drop = ['job_id', 'title', 'location', 'department', 'salary_range',
       'company_profile', 'requirements', 'benefits',
       'telecommuting', 'has_company_logo', 'has_questions', 'employment_type',
       'required_experience', 'required_education', 'industry', 'function']
data = data.drop(columns=columns_to_drop)
data.head()
# Out:
#                                          description  fraudulent
# 0  Food52, a fast-growing, James Beard Award-winn...           0
# 1  Organised - Focused - Vibrant - Awesome!Do you...           0
# 2  Our client, located in Houston, is actively se...           0
# 3  THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4  JOB TITLE: Itemization Review ManagerLOCATION:...           0

# %%
data.isnull().sum()
# Out:
# description    1
# fraudulent     0
# dtype: int64

# %%
# Droping the NAN values in the description column
data.dropna(subset=['description'], inplace=True)
data.isnull().sum()
# Out:
# description    0
# fraudulent     0
# dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data.description, data.fraudulent, test_size=0.2)

# %%
X_train.shape
# Out:
# (14303,)

# %%
X_test.shape
# Out:
# (3576,)

# %%
type(X_train)
# Out:
# pandas.core.series.Series

# %%
X_train[:14]
# Out:
# 7565     We are currently seeking a Customer Service Te...
# 65       We are a boutique digital agency based in Auck...
# 4606     Do you have HR experience? Are you looking to ...
# 15999    If working in a cubical seems like your idea o...
# 15198    John’s Family Grill is a local restaurant that...
# 9105     We are looking for a highly motivated and qual...
# 7682     Title: Senior Media PlannerLocation: Boca Rato...
# 7783     Summer Internships @ Jungle VenturesPositions:...
# 3886     As the TradeGecko Head of Operations, you will...
# 17452    We are the first online-driven solution provid...
# 2566     BI Developer - AnalystJob Details:- Requiremen...
# 7697     International Cultural Exchange Services (ICES...
# 10396    As Director of Software Engineering's newly fo...
# 14469    Critical Nurse Staffing, Inc. is looking for a...
# Name: description, dtype: object

# %%
y_train
# Out:
# 7565     0
# 65       0
# 4606     0
# 15999    0
# 15198    0
#         ..
# 16538    0
# 14353    0
# 17074    0
# 5194     0
# 15542    0
# Name: fraudulent, Length: 14303, dtype: int64

# %%
y_test
# Out:
# 12678    0
# 7205     0
# 14411    0
# 3021     0
# 14723    0
#         ..
# 13640    0
# 5719     0
# 9369     0
# 6337     0
# 14572    0
# Name: fraudulent, Length: 3576, dtype: int64

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
type(X_train.values)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Create bag of words representation using CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

v = CountVectorizer()

X_train_cv = v.fit_transform(X_train.values)
X_train_cv
# Out:
# <14303x55299 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1571535 stored elements in Compressed Sparse Row format>

# %%
X_train_cv.toarray()[:2][0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
X_train_cv.shape
# Out:
# (14303, 55299)

# %%
v.get_feature_names_out()[30862]
# Out:
# 'nouba'

# %%
v.vocabulary_
# Out:
# {'we': 52420,
#  'are': 3915,
#  'currently': 11633,
#  'seeking': 42237,
#  'customer': 11657,
#  'service': 42471,
#  'team': 47064,
#  'lead': 25850,
#  'the': 47956,
#  'right': 40806,
#  'candidate': 7431,
#  'will': 52835,
#  'be': 5457,
#  'an': 2858,
#  'integral': 23788,
#  'part': 32997,
#  'of': 31267,
#  'our': 32415,
#  'talented': 46774,
#  'supporting': 46141,
#  'continued': 10647,
#  'growth': 20988,
#  'this': 48136,
#  'position': 34971,
#  'located': 26612,
#  'in': 22866,
#  'philadelphia': 33886,
#  'pa': 32705,
#  'location': 26615,
#  'responsibilities': 40003,
#  'include': 22921,
#  'but': 7041,
#  'not': 30817,
#  'limited': 26374,
#  'to': 48513,
#  'coordinate': 10863,
#  'work': 53071,
#  'for': 19256,
#  'associates': 4418,
#  'process': 36009,
#  'mail': 27023,
#  'deliver': 12622,
#  'scan': 41774,
#  'out': 32429,
#  'packages': 32728,
#  'and': 3049,
#  'image': 22597,
#  'documents': 14503,
#  'ensure': 16482,
#  'each': 15155,
#  'document': 14434,
#  'is': 24423,
#  'scanned': 41776,
#  'interact': 23885,
#  'with': 52961,
#  'scanning': 41784,
#  'software': 43814,
#  'indicate': 23069,
#  'when': 52734,
#  'batch': 5396,
#  'complete': 9902,
#  'perform': 33531,
#  'quality': 37664,
#  'assurance': 4452,
#  'review': 40605,
#  'images': 22603,
#  'that': 47948,
#  'have': 21460,
#  'been': 5529,
#  'flagged': 18962,
#  'by': 7079,
#  'system': 46442,
#  'productivity': 36359,
#  'sheet': 42873,
#  'track': 48852,
#  'project': 36796,
#  'progress': 36769,
#  'provide': 37270,
#  'numbers': 30948,
#  'billing': 5878,
#  'purposesrun': 37500,
#  'meter': 28756,
#  'inserter': 23586,
#  'equipmenthandle': 16850,
#  'time': 48313,
#  'off': 31281,
#  'requests': 39426,
#  'day': 12199,
#  'processes': 36057,
#  'teamhelp': 47156,
#  'resolve': 39891,
#  'employee': 16032,
#  'concerns': 10142,
#  'issuesadministrative': 24485,
#  'services': 42522,
#  'processing': 36157,
#  'large': 25713,
#  'volume': 52071,
#  'reports': 39232,
#  'using': 51259,
#  'excel': 17399,
#  'assisting': 4407,
#  'manager': 27450,
#  'quarterly': 37741,
#  'business': 6912,
#  'reviewslift': 40639,
#  'bundles': 6863,
#  'make': 27148,
#  'deliverieshandle': 12670,
#  'sensitive': 42371,
#  'materialperform': 28085,
#  'duties': 15033,
#  'special': 44295,
#  'as': 4144,
#  'assigned': 4308,
#  'managementbalance': 27267,
#  'workload': 53163,
#  'guidance': 21084,
#  'direction': 13975,
#  'serve': 42435,
#  'focal': 19151,
#  'point': 34779,
#  'communication': 9527,
#  'company': 9682,
#  'personnelensure': 33749,
#  'operating': 31749,
#  'standards': 44884,
#  'met': 28733,
#  'based': 5283,
#  'on': 31555,
#  'objectivesmaintain': 31122,
#  'accuracy': 1583,
#  'required': 39473,
#  'logs': 26715,
#  'measurementsensure': 28315,
#  'highest': 21764,
#  'levels': 26179,
#  'careensure': 7615,
#  'adherence': 1954,
#  'guidelines': 21097,
#  'safety': 41399,
#  'amp': 2833,
#  'security': 42204,
#  'proceduresresponsible': 35988,
#  'all': 2636,
#  'aspects': 4230,
#  'equipment': 16830,
#  'appropriate': 3690,
#  'recommendationsprovide': 38335,
#  'constructive': 10478,
#  'feedback': 18516,
#  'recognition': 38299,
#  'teamsupport': 47354,
#  'financial': 18797,
#  'results': 40409,
#  'minimizing': 29096,
#  'site': 43248,
#  'waste': 52341,
#  'rework': 40704,
#  'boutique': 6346,
#  'digital': 13898,
#  'agency': 2382,
#  'auckland': 4673,
#  'serving': 42670,
#  'wide': 52799,
#  'range': 38006,
#  'clients': 8805,
#  'including': 22952,
#  'some': 44088,
#  'new': 30531,
#  'zealand': 53682,
#  'best': 5757,
#  'known': 25430,
#  'most': 29622,
#  'loved': 26805,
#  'consumer': 10530,
#  'brands': 6441,
#  'immediate': 22631,
#  'need': 30173,
#  'promising': 37018,
#  'developer': 13447,
#  'do': 14399,
#  'you': 53591,
#  'hr': 22153,
#  'experience': 17718,
#  'looking': 26756,
#  'join': 24958,
#  'rapidly': 38022,
#  'growing': 20977,
#  'startup': 45010,
#  'chance': 8144,
#  'scrappy': 42004,
#  'enough': 16445,
#  'also': 2713,
#  'take': 46743,
#  'office': 31335,
#  'management': 27239,
#  'if': 22503,
#  'so': 43753,
#  'want': 52275,
#  'talk': 46788,
#  'about': 1261,
#  'joining': 24962,
#  'taskus': 46983,
#  'role': 41010,
#  'perfect': 33521,
#  'opportunity': 31947,
#  'someone': 44093,
#  'few': 18619,
#  'years': 53512,
#  'next': 30580,
#  'step': 45138,
#  'their': 47976,
#  'career': 7616,
#  'dual': 14966,
#  'building': 6805,
#  'managing': 27594,
#  'human': 22225,
#  'resources': 39922,
#  'policies': 34813,
#  'operations': 31768,
#  'hq': 22150,
#  'person': 33699,
#  'responsible': 40344,
#  'handling': 21309,
#  'boarding': 6121,
#  'trainingmaintaining': 48974,
#  'handbook': 21286,
#  'other': 32365,
#  'related': 38803,
#  'employment': 16088,
#  'making': 27173,
#  'sure': 46199,
#  'compliance': 9945,
#  'current': 11631,
#  'upcoming': 50003,
#  'regulationsmanaging': 38735,
#  'annual': 3220,
#  '360': 691,
#  'appraisal': 3627,
#  'processimplementing': 36156,
#  'training': 48944,
#  'development': 13509,
#  'programs': 36709,
#  'organizationpreparing': 32226,
#  'bi': 5816,
#  'weekly': 52590,
#  'payroll': 33340,
#  'coordination': 10867,
#  'financeoverseeing': 18788,
#  'benefit': 5667,
#  'programsmaintaining': 36734,
#  'personnel': 33743,
#  'filesassisting': 18714,
#  'hiring': 21823,
#  'managers': 27545,
#  'future': 19976,
#  'recruiting': 38456,
#  'effortsas': 15508,
#  'efficient': 15477,
#  'self': 42302,
#  'starter': 44991,
#  'maintains': 27105,
#  'motivating': 29645,
#  'workplace': 53196,
#  'ensuring': 16489,
#  'there': 48056,
#  'hot': 22055,
#  'coffee': 9225,
#  'every': 17325,
#  'morning': 29609,
#  'clean': 8685,
#  'kitchen': 25333,
#  'nightmanaging': 30630,
#  'inventory': 24205,
#  'from': 19717,
#  'post': 35097,
#  'its': 24657,
#  'energy': 16218,
#  'drinks': 14870,
#  'keeping': 25196,
#  'costs': 11042,
#  'within': 52975,
#  'monthly': 29504,
#  'budgetmaintaining': 6732,
#  'creative': 11304,
#  'which': 52744,
#  'includes': 22943,
#  'scheduling': 41874,
#  'janitorial': 24732,
#  'gardening': 20097,
#  'catering': 7837,
#  'servicessupporting': 42627,
#  'employees': 16038,
#  'it': 24600,
#  'requestsbeing': 39431,
#  'first': 18895,
#  'friendly': 19700,
#  'face': 18164,
#  'visitorsowning': 51941,
#  'expansion': 17621,
#  'into': 24132,
#  'adjacent': 1972,
#  'space': 44208,
#  'contractors': 10674,
#  'furniture': 19959,
#  'suppliersrunning': 46072,
#  'errands': 16936,
#  'around': 4050,
#  'santa': 41618,
#  'monica': 29451,
#  'organizing': 32266,
#  'fun': 19801,
#  'activities': 1767,
#  'like': 26350,
#  'lunches': 26892,
#  'happy': 21359,
#  'hours': 22080,
#  'occasional': 31200,
#  'yacht': 53472,
#  'adventure': 2163,
#  'working': 53152,
#  'cubical': 11544,
#  'seems': 42244,
#  'your': 53614,
#  'idea': 22396,
#  'hell': 21617,
#  'then': 48041,
#  'awesome': 4965,
#  'might': 28987,
#  've': 51534,
#  'waiting': 52220,
#  're': 38116,
#  'singaporean': 43213,
#  'venture': 51615,
#  'backed': 5024,
#  'b2b': 5000,
#  'saas': 41360,
#  'opening': 31711,
#  'philippines': 33894,
#  'resourceful': 39912,
#  'clever': 8747,
#  'opinionated': 31848,
#  'should': 43009,
#  'adjectives': 1973,
#  'used': 51179,
#  'describe': 12990,
#  'unique': 49837,
#  'personality': 33715,
#  'happiness': 21356,
#  'satisfaction': 41660,
#  'game': 20054,
#  'aim': 2496,
#  'win': 52866,
#  'responsibilitieswe': 40307,
#  'experienced': 17768,
#  'support': 46108,
#  'leader': 25859,
#  'help': 21628,
#  'us': 51134,
#  'scale': 41754,
#  'up': 49995,
#  'learn': 25976,
#  'more': 29578,
#  'month': 29497,
#  'than': 47939,
#  'would': 53300,
#  'year': 53495,
#  'normal': 30772,
#  'general': 20221,
#  'tradegecko': 48884,
#  'grow': 20971,
#  'customers': 11673,
#  'properly': 37087,
#  'taken': 46747,
#  'cared': 7612,
#  'll': 26544,
#  'coach': 9105,
#  'leadergrow': 25864,
#  'manage': 27229,
#  'staff': 44713,
#  'communicate': 9520,
#  'engage': 16235,
#  'key': 25246,
#  'global': 20473,
#  'markets': 27944,
#  'path': 33205,
#  'successyou': 45807,
#  'proactive': 35820,
#  'ready': 38145,
#  'control': 10729,
#  'own': 32661,
#  'together': 48552,
#  'can': 7409,
#  'set': 42701,
#  'objectives': 31089,
#  'who': 52777,
#  'needs': 30302,
#  'charge': 8256,
#  'create': 11283,
#  'success': 45759,
#  'useful': 51183,
#  'skillsknowledge': 43471,
#  'ecosystem': 15291,
#  'plussimilar': 34708,
#  'technical': 47402,
#  'specifically': 44342,
#  'plusgoogle': 34686,
#  'apps': 3762,
#  'gmail': 20512,
#  'docs': 14422,
#  'calendars': 7193,
#  'zendeskgood': 53695,
#  'written': 53354,
#  'englishexperience': 16390,
#  'ms': 29737,
#  'officeswriting': 31411,
#  'web': 52448,
#  'content': 10586,
#  'creating': 11291,
#  'experienceif': 17811,
#  'think': 48113,
#  'what': 52720,
#  'takes': 46757,
#  'handle': 21302,
#  'group': 20935,
#  'hardworking': 21396,
#  'sarcastic': 41639,
#  'miscreants': 29159,
#  'apply': 3585,
#  'now': 30881,
#  'john': 24955,
#  'family': 18303,
#  'grill': 20891,
#  'local': 26592,
#  'restaurant': 40366,
#  'dedicated': 12474,
#  'waitresses': 52223,
#  'honest': 21968,
#  'loyal': 26828,
#  'enthusiastic': 16528,
#  'must': 29858,
#  'come': 9405,
#  'well': 52650,
#  'groomed': 20912,
#  'prepared': 35512,
#  'great': 20838,
#  'atmosphere': 4519,
#  'receive': 38244,
#  'needed': 30175,
#  'gracefully': 20735,
#  'at': 4486,
#  'very': 51733,
#  'helpful': 21638,
#  'shifts': 42910,
#  'provided': 37273,
#  'upon': 50078,
#  'request': 39396,
#  'whether': 52743,
#  'job': 24889,
#  'or': 32075,
#  'monday': 29425,
#  'through': 48201,
#  'saturday': 41698,
#  '00': 0,
#  'am': 2750,
#  'pm': 34725,
#  'sundays': 45952,
#  'open': 31695,
#  'information': 23259,
#  'given': 20428,
#  'interested': 23942,
#  'wages': 52209,
#  'discussed': 14179,
#  'hard': 21376,
#  'cooks': 10839,
#  'able': 1256,
#  'busy': 7040,
#  'conditions': 10195,
#  'available': 4874,
#  'days': 12223,
#  'week': 52565,
#  'please': 34626,
#  'look': 26750,
#  'above': 1270,
#  'consider': 10388,
#  'offering': 31301,
#  'place': 34268,
#  'dplease': 14791,
#  'submit': 45684,
#  'resume': 40464,
#  'touch': 48775,
#  'thanks': 47944,
#  'highly': 21775,
#  'motivated': 29635,
#  'qualified': 37652,
#  'administrator': 2043,
#  'fast': 18375,
#  'paced': 32710,
#  'dynamic': 15130,
#  'challenging': 8131,
#  'environment': 16610,
#  'give': 20425,
#  'entry': 16570,
#  'level': 26143,
#  'specializing': 44333,
#  'entitlement': 16543,
#  'ideal': 22398,
#  'candidates': 7443,
#  'demonstrate': 12774,
#  'strong': 45518,
#  'conceptual': 10129,
#  'understanding': 49748,
#  'networking': 30480,
#  'ability': 1247,
#  'following': 19208,
#  'assist': 4372,
#  'issues': 24480,
#  'supported': 46124,
#  'servicesdocument': 42558,
#  'report': 39151,
#  'requestsprovide': 39452,
#  '24x7': 536,
#  'coverage': 11169,
#  'teambe': 47090,
#  'via': 51761,
#  'cell': 7940,
#  'phone': 33911,
#  'email': 15717,
#  'case': 7732,
#  'emergencyperforms': 15994,
#  'administration': 2005,
#  'functions': 19847,
#  'both': 6311,
#  'mainframe': 27078,
#  'distributed': 14299,
#  'systemsmanage': 46589,
#  'user': 51194,
#  'accounts': 1485,
#  'systems': 46520,
#  'applications': 3473,
#  'databases': 12047,
#  'common': 9509,
#  'computing': 10080,
#  'systemsthis': 46632,
#  'full': 19787,
#  'direct': 13965,
#  'montreal': 29546,
#  'salary': 41435,
#  'qualifications': 37625,
#  'title': 48489,
#  'senior': 42352,
#  'media': 28352,
#  'plannerlocation': 34338,
#  'boca': 6148,
#  'raton': 38076,
#  'flsalary': 19106,
#  '50': 834,
#  '000': 1,
#  '70': 984,
#  'benefits': 5672,
#  'summaryseeking': 45927,
#  'sr': 44644,
#  'planner': 34336,
#  'fl': 18959,
#  'effectively': 15418,
#  'planning': 34341,
#  'efforts': 15506,
#  'research': 39755,
#  'buying': 7056,
#  'print': 35739,
#  'posting': 35119,
#  'facets': 18180,
#  'his': 21828,
#  'her': 21668,
#  'market': 27835,
#  'plans': 34398,
#  'organizes': 32265,
#  'implements': 22755,
#  'controls': 10763,
#  'buy': 7052,
#  'serves': 42469,
#  'resource': 39909,
#  'developing': 13508,
#  'sound': 44153,
#  'buys': 7062,
#  'increase': 22990,
#  'traffic': 48910,
#  'sales': 41452,
#  'negotiates': 30387,
#  'rates': 38048,
#  'added': 1906,
#  'value': 51432,
#  'utilizes': 51331,
#  'tools': 48630,
#  'computer': 10067,
#  'books': 6249,
#  'client': 8761,
#  'marketplace': 27933,
#  'driving': 14906,
#  'patterns': 33242,
#  'etc': 17080,
#  'qualitativequantitativetrendshour': 37660,
#  'hour': 22072,
#  'planningzip': 34383,
#  'code': 9155,
#  'analysisconstantly': 2903,
#  'communicates': 9524,
#  'account': 1421,
#  'executivesanalyzes': 17534,
#  'times': 48411,
#  'assistant': 4384,
#  'stations': 45071,
#  'move': 29683,
#  'spots': 44547,
#  'accordingly': 1410,
#  'necessary': 30107,
#  'constantly': 10448,
#  'vendorswork': 51602,
#  'broadcast': 6594,
#  'buyers': 7055,
#  'plan': 34297,
#  'intervene': 24085,
#  'facilitate': 18185,
#  'wellobtaining': 52663,
#  'additional': 1918,
#  'remotes': 39038,
#  'no': 30701,
#  'charges': 8265,
#  'sponsorships': 44517,
#  'billboards': 5875,
#  'clientsfinding': 8873,
#  'innovative': 23522,
#  'methods': 28793,
#  '10': 78,
#  'frequency': 19655,
#  'creation': 11292,
#  'features': 18463,
#  'tailored': 46734,
#  'strictly': 45495,
#  'having': 21469,
#  'discussions': 14184,
#  'station': 45066,
#  'promotion': 37030,
#  'ideas': 22405,
#  'checking': 8330,
#  'analyzing': 3038,
#  'invoices': 24282,
#  'receiving': 38251,
#  'good': 20655,
#  'grps': 21031,
#  'under': 49710,
#  'delivering': 12685,
#  'analysis': 2882,
#  'performance': 33533,
#  'negotiate': 30385,
#  'over': 32537,
#  'deliverresearch': 12689,
#  'wellprovides': 52664,
#  'plannersassists': 34340,
#  'implementation': 22707,
#  'pitch': 34227,
#  'presentationsdiscusses': 35578,
#  'travel': 49117,
#  'summer': 45942,
#  'internships': 24038,
#  'jungle': 25089,
#  'venturespositions': 51624,
#  'pr': 35243,
#  'executives': 17533,
#  'social': 43769,
#  'advertising': 2184,
#  'choose': 8468,
#  'any': 3298,
#  'mentioned': 28635,
#  'positions': 35013,
#  'depending': 12915,
#  'choice': 8462,
#  'head': 21508,
#  'tasked': 46899,
#  'closely': 8995,
#  'ceo': 7997,
#  'setting': 42726,
#  'running': 41319,
#  'lot': 26782,
#  'core': 10939,
#  'has': 21434,
#  'tripled': 49259,
#  'already': 2711,
#  'hold': 21886,
#  'reins': 38779,
#  'excellent': 17419,
#  'organisation': 32162,
#  'skills': 43372,
#  'being': 5586,
#  'sort': 44137,
#  'loves': 26815,
#  'checklists': 8337,
#  'oiled': 31487,
#  'machines': 26950,
#  'things': 48104,
#  'run': 41314,
#  'smoothly': 43710,
#  'okrs': 31503,
#  'aors': 3321,
#  'kpis': 25483,
#  'feel': 18553,
#  'warm': 52308,
#  'fuzzy': 20000,
#  'inside': 23591,
#  'people': 33468,
#  'toes': 48549,
#  'engines': 16376,
#  'excite': 17458,
#  'specialist': 44305,
#  'connector': 10349,
#  'arbiter': 3826,
#  'between': 5792,
#  'functional': 19807,
#  'areas': 3947,
#  'hands': 21324,
#  'accounting': 1473,
#  'infrastructure': 23331,
#  'marketing': 27866,
#  'important': 22769,
#  'qualms': 37715,
#  'getting': 20346,
#  'dirty': 14062,
#  'white': 52762,
#  'gloves': 20497,
#  'here': 21678,
#  'same': 41562,
#  'judgment': 25058,
#  'struggle': 45544,
#  'bit': 5966,
#  'they': 48095,
#  'learnjoin': 26003,
#  'build': 6801,
#  'foundations': 19484,
#  'skyscraper': 43569,
#  'online': 31620,
#  'driven': 14880,
#  'solution': 43922,
#  'provider': 37286,
#  'heating': 21579,
#  'efficiency': 15453,
#  'speed': 44420,
#  'excellence': 17408,
#  'offline': 31425,
#  'delivery': 12691,
#  'teams': 47253,
#  'generate': 20230,
#  'cheaper': 8321,
#  'greener': 20860,
#  'heat': 21575,
#  'households': 22114,
#  'funded': 19917,
#  '18': 273,
#  'led': 26033,
#  'founders': 19489,
#  '15': 221,
#  'internet': 24014,
#  'industries': 23140,
#  'designers': 13185,
#  'intuitive': 24178,
#  'interfaces': 23953,
#  'engineering': 16292,
#  'design': 13140,
#  'mostly': 29623,
#  'angularjs': 3177,
#  'javascript': 24762,
#  'variety': 51495,
#  'frontends': 19723,
#  'connect': 10329,
#  'standardized': 44881,
#  'api': 3347,
#  'better': 5781,
#  'understand': 49743,
#  'users': 51199,
#  'analytics': 3000,
#  'analystjob': 2984,
#  'details': 13372,
#  'requirements': 39594,
#  'proven': 37268,
#  'designer': 13175,
#  'complexdwh': 9936,
#  'expertise': 17935,
#  'data': 12014,
#  'warehouse': 52293,
#  'domain': 14649,
#  'intelligenceimplementation': 23856,
#  'providing': 37302,
#  'clear': 8708,
#  'accurate': 1604,
#  'designdocuments': 13170,
#  'guiding': 21138,
#  'during': 15027,
#  'least': 26017,
#  'one': 31592,
#  'leading': 25907,
#  'reporting': 39161,
#  'platform': 34480,
#  'cognos': 9239,
#  'objects': 31151,
#  'facing': 18216,
#  'skillsincluding': 43466,
#  'presentations': 35570,
#  'audience': 4685,
#  'greatcommunication': 20839,
#  'spoken': 44503,
#  'english': 16383,
#  'verygood': 51734,
#  'sql': 44613,
#  'become': 5502,
#  'trusted': 49335,
#  'advisor': 2219,
#  'travelmight': 49139,
#  'assignment': 4347,
#  'involves': 24322,
#  'negotiable': 30384,
#  'instruments': 23740,
#  'personal': 33704,
#  'employeedata': 16033,
#  'could': 11069,
#  'commit': 9482,
#  'fraudulent': 19610,
#  'act': 1711,
#  'cash': 7758,
#  'securities': 42202,
#  'efts': 15553,
#  'exclusiveto': 17473,
#  'banking': 5198,
#  'lockbox': 26652,
#  'programming': 36688,
#  'skill': 43364,
#  'com': 9392,
#  'international': 23999,
#  'cultural': 11563,
#  'exchange': 17444,
#  'ices': 22375,
#  'non': 30736,
#  'profit': 36611,
#  'organization': 32192,
#  'opportunities': 31864,
#  'young': 53609,
#  'europe': 17189,
#  'asia': 4193,
#  'south': 44185,
#  'america': 2800,
#  'spend': 44436,
#  'school': 41917,
#  'semester': 42335,
#  'host': 22045,
#  '20': 380,
#  'educational': 15376,
#  'show': 43016,
#  'many': 27770,
#  'nations': 30022,
#  'eye': 18121,
#  'immersed': 22645,
#  'society': 43789,
#  'foreign': 19310,
#  'country': 11118,
#  'result': 40406,
#  'real': 38152,
#  'diversity': 14342,
#  'appreciation': 3645,
#  'qualities': 37662,
#  'countries': 11110,
#  'cultures': 11581,
#  'increased': 22991,
#  'esteem': 17044,
#  'confidence': 10243,
#  'developed': 13440,
#  'recognize': 38305,
#  'solve': 44050,
#  'problems': 35851,
#  'multi': 29779,
#  'perspective': 33774,
#  'professional': 36524,
#  'individuals': 23112,
#  'finding': 18818,
#  'homes': 21953,
#  'these': 48078,
#  'wonderful': 53030,
#  'students': 45560,
#  'coordinator': 10878,
#  'generating': 20234,
#  'interest': 23941,
#  'community': 9596,
#  'completing': 9916,
#  'paperwork': 32903,
#  'families': 18300,
#  'hosting': 22053,
#  'orientations': 32281,
#  'visitors': 51930,
#  'adjustment': 1981,
#  'positive': 35043,
#  'life': 26289,
#  'changing': 8185,
#  'exposure': 18021,
#  'provides': 37301,
#  'tons': 48602,
#  'coordinators': 10889,
#  'lc': 25837,
#  'paired': 32831,
#  'regional': 38670,
#  'director': 14000,
#  'trains': 49002,
#  'develops': 13673,
#  'coaches': 9109,
#  'throughout': 48208,
#  'placing': 34290,
#  'season': 42145,
#  'answer': 3255,
#  'questions': 37791,
#  'guide': 21093,
#  'placement': 34275,
#  'conference': 10227,
#  'schedule': 41825,
#  'sign': 43098,
#  'listen': 26469,
#  'specified': 44387,
#  'trainer': 48941,
#  'numerous': 30955,
#  'ample': 2835,
#  'guides': 21131,
#  'material': 28066,
#  'student': 45556,
#  'home': 21924,
#  'develop': 13436,
#  'field': 18651,
#  'schools': 41923,
#  'flexibility': 19011,
#  'along': 2704,
#  'another': 3244,
#  'stay': 45109,
#  'parent': 32961,
#  'supervision': 45999,
#  'fees': 18561,
#  'supervise': 45995,
#  'addition': 1917,
#  'offers': 31327,
#  'qualify': 37655,
#  'incentive': 22891,
#  'trip': 49255,
#  'national': 30016,
#  'meeting': 28442,
#  'held': 21611,
#  'once': 31569,
#  'obtaining': 31189,
#  'certain': 8033,
#  'number': 30945,
#  'placements': 34279,
#  'deadlines': 12283,
#  'parents': 32964,
#  'teachers': 47057,
#  'anyone': 3306,
#  'secondary': 42162,
#  'income': 22968,
#  'retirees': 40520,
#  'else': 15706,
#  'wanting': 52278,
#  'difference': 13859,
#  'send': 42344,
#  'copy': 10913,
#  'contact': 10548,
#  'name': 29966,
#  'follow': 19196,
#  'timely': 48383,
#  'manner': 27649,
#  'newly': 30545,
#  'forming': 19391,
#  'york': 53579,
#  'player': 34590,
#  'contribute': 10713,
#  'drive': 14874,
#  'high': 21758,
#  'architecture': 3860,
#  'roll': 41098,
#  'sleeves': 43601,
#  'inspire': 23645,
#  'mentor': 28642,
#  'superb': 45967,
#  '30': 616,
#  'deep': 12492,
#  'edge': 15317,
#  'technologies': 47461,
#  'motivation': 29646,
#  'leadership': 25875,
#  'aggressive': 2420,
#  'double': 14737,
#  'size': 43332,
#  'again': 2349,
#  'insights': 23605,
#  'decide': 12394,
#  'directions': 13989,
#  'while': 52749,
#  'preserving': 35609,
#  'values': 51444,
#  ...}

# %%
X_train_np = X_train_cv.toarray()
X_train_np[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
np.where(X_train_np[0]!=0)
# Out:
# (array([ 1583,  1954,  2636,  2833,  2858,  3049,  3690,  3915,  4144,
#          4230,  4308,  4407,  4418,  4452,  5283,  5396,  5457,  5529,
#          5878,  6863,  6912,  7041,  7079,  7431,  7615,  9527,  9682,
#          9902, 10142, 10478, 10647, 10863, 11633, 11657, 12199, 12622,
#         12670, 13975, 14434, 14503, 15033, 15155, 16032, 16482, 16830,
#         16850, 17399, 18516, 18797, 18962, 19151, 19256, 20988, 21084,
#         21097, 21460, 21764, 22597, 22603, 22866, 22921, 23069, 23586,
#         23788, 23885, 24423, 24485, 25713, 25850, 26179, 26374, 26612,
#         26615, 26715, 27023, 27148, 27267, 27450, 28085, 28315, 28733,
#         28756, 29096, 30817, 30948, 31122, 31267, 31281, 31555, 31749,
#         32415, 32429, 32705, 32728, 32997, 33531, 33749, 33886, 34779,
#         34971, 35988, 36009, 36057, 36157, 36359, 36769, 36796, 37270,
#         37500, 37664, 37741, 38299, 38335, 39232, 39426, 39473, 39891,
#         40003, 40409, 40605, 40639, 40704, 40806, 41399, 41774, 41776,
#         41784, 42204, 42237, 42371, 42435, 42471, 42522, 42873, 43248,
#         43814, 44295, 44884, 46141, 46442, 46774, 47064, 47156, 47354,
#         47948, 47956, 48136, 48313, 48513, 48852, 51259, 52071, 52341,
#         52420, 52734, 52835, 52961, 53071, 53163], dtype=int64),)

# %%
X_train
# Out:
# 7565     We are currently seeking a Customer Service Te...
# 65       We are a boutique digital agency based in Auck...
# 4606     Do you have HR experience? Are you looking to ...
# 15999    If working in a cubical seems like your idea o...
# 15198    John’s Family Grill is a local restaurant that...
#                                ...
# 16538    Escrow Officer -Houston A well established, we...
# 14353    Bring it all together as our new Associate Cre...
# 17074    This is who we are: Network Closing Services, ...
# 5194     The Service Delivery Manager 1 will be located...
# 15542    Crypteia Networks is looking for a devops engi...
# Name: description, Length: 14303, dtype: object

# %%
X_train[:4][7565]
# Out:
# 'We are currently seeking a Customer Service Team Lead. The right candidate will be an integral part of our talented team, supporting our continued growth. This position will be located in our Philadelphia, PA location.Responsibilities include, but are not limited to:Coordinate work for Customer Service Associates.Process mail, deliver mail, scan in/out packages and deliver mail/packages.Scan/Image\xa0to include; scan documents, ensure each document is scanned,\xa0interact with scanning software to indicate when a batch is complete, perform quality assurance and review images, perform quality assurance of documents that have been flagged by the system, and complete Productivity Sheet to track project progress and provide numbers for billing purposesRun mail meter and inserter equipmentHandle time-off requests and day-to-day processes of the teamHelp resolve employee and customer concerns/issuesAdministrative services/processing large volume reports using excel and assisting manager with quarterly business reviewsLift large bundles of mail and make mail deliveriesHandle time-sensitive materialPerform duties and special requests as assigned by managementBalance workload; provide guidance and direction to team; serve as focal point for communication with customer and company personnelEnsure operating and quality standards are met based on service objectivesMaintain accuracy of required reports, logs and measurementsEnsure the highest levels of customer careEnsure adherence to business guidelines, safety &amp; security proceduresResponsible for all aspects of equipment; make appropriate equipment recommendationsProvide constructive feedback and recognition to teamSupport financial results by minimizing site waste and rework'

# %% [markdown]
# ## Train the naive bayes model

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_cv, y_train)
# Out:
# MultinomialNB()

# %%
X_test_cv = v.transform(X_test)

# %% [markdown]
# ## Evaluate Performance

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(X_test_cv)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3392
#            1       0.75      0.43      0.54       184
#
#     accuracy                           0.96      3576
#    macro avg       0.86      0.71      0.76      3576
# weighted avg       0.96      0.96      0.96      3576

# %%
emails = [
    'Hey mohan, can we get together to watch footbal game tomorrow?',
    'Upto 20% discount on parking, exclusive offer just for you. Dont miss this reward!'
]

emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 0], dtype=int64)

# %%
emails = ['We saw your profile on Indeed and thought you would be a great match for the Mathematics Instructor-NUC Online opportunity.Please submit a quick application incase you have an interest.',
          'We saw your profile on Indeed and thought you would be a great match for the Digital Data Analyst opportunity. Please submit a quick application if you have any interest.'
]
emails_count = v.transform(emails)
model.predict(emails_count)
# Out:
# array([0, 0], dtype=int64)

# %% [markdown]
# ## Train the model using sklearn pipeline and reduce number of lines of code

# %%
from sklearn.pipeline import Pipeline

clf = Pipeline([
    ('vectorizer', CountVectorizer()),
    ('nb', MultinomialNB())
])

# %%
clf.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer()), ('nb', MultinomialNB())])

# %% [markdown]
# ## Evaluate Performance

# %%
y_pred = clf.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      3392
#            1       0.75      0.43      0.54       184
#
#     accuracy                           0.96      3576
#    macro avg       0.86      0.71      0.76      3576
# weighted avg       0.96      0.96      0.96      3576
